# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#
# Project 2, starter code Part a
#

import math
import tensorflow as tf
import numpy as np
import pylab as plt
import pickle
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
NUM_CLASSES = 10
IMG_SIZE = 32
NUM_CHANNELS = 3
learning_rate = 0.001
epochs = 1000
batch_size = 128

seed = 10
np.random.seed(seed)
tf.set_random_seed(seed)

# %%
def load_data(file):
    with open(file, 'rb') as fo:
        try:
            samples = pickle.load(fo)
        except UnicodeDecodeError:  #python 3.x
            fo.seek(0)
            samples = pickle.load(fo, encoding='latin1')

    data, labels = samples['data'], samples['labels']

    data = np.array(data, dtype=np.float32)
    labels = np.array(labels, dtype=np.int32)


    labels_ = np.zeros([labels.shape[0], NUM_CLASSES])
    labels_[np.arange(labels.shape[0]), labels-1] = 1

    return data, labels_

# %%
def cnn(images, c1_filters, c2_filters):
    images = tf.reshape(images, [-1, IMG_SIZE, IMG_SIZE, NUM_CHANNELS])

    # C1 (50x24x24): Conv layer, 50 filters, window size 9x9, VALID padding, ReLU
    # S1 (50x12x12): Max pooling layer, window size 2x2, stride = 2, VALID padding
    W1 = tf.Variable(tf.truncated_normal([9, 9, NUM_CHANNELS, c1_filters], stddev=1.0/np.sqrt(NUM_CHANNELS*9*9)), name='weights_1')
    b1 = tf.Variable(tf.zeros([c1_filters]), name='biases_1')  
    conv_1 = tf.nn.relu(tf.nn.conv2d(images, W1, [1, 1, 1, 1], padding='VALID') + b1)
    pool_1 = tf.nn.max_pool(conv_1, ksize= [1, 2, 2, 1], strides= [1, 2, 2, 1], padding='VALID', name='pool_1')

    # C2 (60x8x8): Conv layer, 60 filters, window size 5x5, VALID padding, ReLU
    # S2 (60x4x4): Max pooling layer, window size 2x2, stride = 2, VALID padding
    W2 = tf.Variable(tf.truncated_normal([5, 5, c1_filters, c2_filters], stddev=1.0/np.sqrt(c1_filters*5*5)), name='weights_2')
    b2 = tf.Variable(tf.zeros([c2_filters]), name='biases_2')
    conv_2 = tf.nn.relu(tf.nn.conv2d(pool_1, W2, [1, 1, 1, 1], padding='VALID') + b2)
    pool_2 = tf.nn.max_pool(conv_2, ksize= [1, 2, 2, 1], strides= [1, 2, 2, 1], padding='VALID', name='pool_2')

    # Flatten (dim = 60x4x4 = 960)
    dim = pool_2.get_shape()[1].value * pool_2.get_shape()[2].value * pool_2.get_shape()[3].value 
    pool_2_flat = tf.reshape(pool_2, [-1, dim])

    # F3: Fully connected layer of size 300 (960 -> 300)
    W3 = tf.Variable(tf.truncated_normal([dim, 300], stddev=1.0/np.sqrt(dim)), name='weights_3')
    b3 = tf.Variable(tf.zeros([300]), name='biases_3')
    f3_logits = tf.matmul(pool_2_flat, W3) + b3

    # F4: Softmax layer of size 10 (300 -> 10)
    W4 = tf.Variable(tf.truncated_normal([300, NUM_CLASSES], stddev=1.0/np.sqrt(300)), name='weights_4')
    b4 = tf.Variable(tf.zeros([NUM_CLASSES]), name='biases_4')
    f4_logits = tf.matmul(f3_logits, W4) + b4

    return conv_1, pool_1, conv_2, pool_2, f4_logits

# %%
# Main Program
if __name__ == '__main__':
    trainX, trainY = load_data('/content/drive/My Drive/NTU - Year 3 Sem 1/CZ4042 Neural Network/Project 2/data_batch_1')
    print(trainX.shape, trainY.shape)

    testX, testY = load_data('/content/drive/My Drive/NTU - Year 3 Sem 1/CZ4042 Neural Network/Project 2/test_batch_trim')
    print(testX.shape, testY.shape)

    # Scaling the train & test inputs
    trainX = (trainX - np.min(trainX, axis = 0))/np.max(trainX, axis = 0)
    testX = (testX - np.min(testX, axis = 0))/np.max(testX, axis = 0)

    # Create the model
    x = tf.placeholder(tf.float32, [None, NUM_CHANNELS*IMG_SIZE*IMG_SIZE]) # 3x32x32
    y_ = tf.placeholder(tf.float32, [None, NUM_CLASSES])

    c1, s1, c2, s2, logits = cnn(x, 310, 210)

    cross_entropy = tf.nn.softmax_cross_entropy_with_logits_v2(labels=y_, logits=logits)
    loss = tf.reduce_mean(cross_entropy)

    #   train_step = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss)
    train_step = tf.train.MomentumOptimizer(learning_rate,0.1).minimize(loss)

    correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(y_, 1))
    correct_prediction = tf.cast(correct_prediction, tf.float32)
    accuracy = tf.reduce_mean(correct_prediction)

    N = len(trainX)
    idx = np.arange(N)

    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        train_loss = []
        test_acc = []

        for e in range(epochs):
            np.random.shuffle(idx)
            trainX, trainY = trainX[idx], trainY[idx]
            temp_train_loss = []

            for start, end in zip(range(0, N, batch_size), range(batch_size, N, batch_size)):
                # train_step.run(feed_dict={x: trainX[start:end], y_: trainY[start:end]})
                # temp_train_loss.append(loss.eval(feed_dict={x: trainX[start:end], y_: trainY[start:end]}))
                _, loss_ = sess.run([train_step, loss], {x: trainX[start:end], y_: trainY[start:end]})
                temp_train_loss.append(loss_)

            trainLoss = np.mean(np.array(temp_train_loss))
            testAcc = accuracy.eval(feed_dict={x: testX, y_: testY})
            train_loss.append(trainLoss)
            test_acc.append(testAcc)

            if (e % 10 == 0 or e == epochs-1):
                print('Epoch: ', e, ' | Train loss: ', trainLoss, ' | Test acc: ', testAcc)
# Out:
# (10000, 3072) (10000, 10)
# (2000, 3072) (2000, 10)
# Epoch:  0  | Train loss:  2.2882125  | Test acc:  0.191
# Epoch:  10  | Train loss:  2.0324216  | Test acc:  0.2925
# Epoch:  20  | Train loss:  1.9098178  | Test acc:  0.3175
# Epoch:  30  | Train loss:  1.8489996  | Test acc:  0.3525
# Epoch:  40  | Train loss:  1.8020567  | Test acc:  0.3715
# Epoch:  50  | Train loss:  1.7590858  | Test acc:  0.382
# Epoch:  60  | Train loss:  1.7182397  | Test acc:  0.3955
# Epoch:  70  | Train loss:  1.6806971  | Test acc:  0.4115
# Epoch:  80  | Train loss:  1.6462439  | Test acc:  0.417
# Epoch:  90  | Train loss:  1.6126854  | Test acc:  0.4205
# Epoch:  100  | Train loss:  1.5852555  | Test acc:  0.4335
# Epoch:  110  | Train loss:  1.5566436  | Test acc:  0.4415
# Epoch:  120  | Train loss:  1.5335741  | Test acc:  0.458
# Epoch:  130  | Train loss:  1.5101459  | Test acc:  0.444
# Epoch:  140  | Train loss:  1.4851496  | Test acc:  0.4475
# Epoch:  150  | Train loss:  1.4630196  | Test acc:  0.463
# Epoch:  160  | Train loss:  1.4360995  | Test acc:  0.468
# Epoch:  170  | Train loss:  1.4154214  | Test acc:  0.4695
# Epoch:  180  | Train loss:  1.3940175  | Test acc:  0.474
# Epoch:  190  | Train loss:  1.3744175  | Test acc:  0.4745
# Epoch:  200  | Train loss:  1.3532449  | Test acc:  0.4555
# Epoch:  210  | Train loss:  1.3357009  | Test acc:  0.5015
# Epoch:  220  | Train loss:  1.3169202  | Test acc:  0.4925
# Epoch:  230  | Train loss:  1.3007966  | Test acc:  0.4895
# Epoch:  240  | Train loss:  1.2762578  | Test acc:  0.504
# Epoch:  250  | Train loss:  1.2620133  | Test acc:  0.505
# Epoch:  260  | Train loss:  1.2516278  | Test acc:  0.504
# Epoch:  270  | Train loss:  1.2257719  | Test acc:  0.5005
# Epoch:  280  | Train loss:  1.2071886  | Test acc:  0.5095
# Epoch:  290  | Train loss:  1.1896478  | Test acc:  0.5165
# Epoch:  300  | Train loss:  1.1731623  | Test acc:  0.5025
# Epoch:  310  | Train loss:  1.1592752  | Test acc:  0.5075
# Epoch:  320  | Train loss:  1.1351142  | Test acc:  0.5085
# Epoch:  330  | Train loss:  1.1193241  | Test acc:  0.519
# Epoch:  340  | Train loss:  1.1053426  | Test acc:  0.5225
# Epoch:  350  | Train loss:  1.086094  | Test acc:  0.5105
# Epoch:  360  | Train loss:  1.0660566  | Test acc:  0.521
# Epoch:  370  | Train loss:  1.0611228  | Test acc:  0.515
# Epoch:  380  | Train loss:  1.0336472  | Test acc:  0.5155
# Epoch:  390  | Train loss:  1.0169008  | Test acc:  0.5205
# Epoch:  400  | Train loss:  1.0040591  | Test acc:  0.507
# Epoch:  410  | Train loss:  0.98637813  | Test acc:  0.53
# Epoch:  420  | Train loss:  0.96266633  | Test acc:  0.514
# Epoch:  430  | Train loss:  0.9501526  | Test acc:  0.522
# Epoch:  440  | Train loss:  0.9326721  | Test acc:  0.516
# Epoch:  450  | Train loss:  0.9156891  | Test acc:  0.5205
# Epoch:  460  | Train loss:  0.8928247  | Test acc:  0.5225
# Epoch:  470  | Train loss:  0.87407315  | Test acc:  0.5205
# Epoch:  480  | Train loss:  0.85860324  | Test acc:  0.528
# Epoch:  490  | Train loss:  0.84189254  | Test acc:  0.5175
# Epoch:  500  | Train loss:  0.81866735  | Test acc:  0.519
# Epoch:  510  | Train loss:  0.79721713  | Test acc:  0.5175
# Epoch:  520  | Train loss:  0.7879515  | Test acc:  0.53
# Epoch:  530  | Train loss:  0.7707886  | Test acc:  0.5315
# Epoch:  540  | Train loss:  0.746073  | Test acc:  0.5395
# Epoch:  550  | Train loss:  0.72474766  | Test acc:  0.5275
# Epoch:  560  | Train loss:  0.70648754  | Test acc:  0.5255
# Epoch:  570  | Train loss:  0.69520336  | Test acc:  0.516
# Epoch:  580  | Train loss:  0.6745066  | Test acc:  0.539
# Epoch:  590  | Train loss:  0.65524244  | Test acc:  0.535
# Epoch:  600  | Train loss:  0.6398329  | Test acc:  0.5395
# Epoch:  610  | Train loss:  0.61642444  | Test acc:  0.5295
# Epoch:  620  | Train loss:  0.59274125  | Test acc:  0.542
# Epoch:  630  | Train loss:  0.57342494  | Test acc:  0.529
# Epoch:  640  | Train loss:  0.5605631  | Test acc:  0.5375
# Epoch:  650  | Train loss:  0.54038334  | Test acc:  0.536
# Epoch:  660  | Train loss:  0.5180379  | Test acc:  0.5325
# Epoch:  670  | Train loss:  0.49786583  | Test acc:  0.521
# Epoch:  680  | Train loss:  0.4877713  | Test acc:  0.5405
# Epoch:  690  | Train loss:  0.47104758  | Test acc:  0.5415
# Epoch:  700  | Train loss:  0.4549967  | Test acc:  0.5335
# Epoch:  710  | Train loss:  0.43609282  | Test acc:  0.538
# Epoch:  720  | Train loss:  0.4148276  | Test acc:  0.531
# Epoch:  730  | Train loss:  0.3993846  | Test acc:  0.5305
# Epoch:  740  | Train loss:  0.38950658  | Test acc:  0.5375
# Epoch:  750  | Train loss:  0.3665148  | Test acc:  0.54
# Epoch:  760  | Train loss:  0.35650194  | Test acc:  0.513
# Epoch:  770  | Train loss:  0.3359472  | Test acc:  0.5375
# Epoch:  780  | Train loss:  0.32299185  | Test acc:  0.543
# Epoch:  790  | Train loss:  0.31096908  | Test acc:  0.543
# Epoch:  800  | Train loss:  0.29538608  | Test acc:  0.528
# Epoch:  810  | Train loss:  0.2878006  | Test acc:  0.5315
# Epoch:  820  | Train loss:  0.26848194  | Test acc:  0.5385
# Epoch:  830  | Train loss:  0.25852942  | Test acc:  0.5345
# Epoch:  840  | Train loss:  0.24583976  | Test acc:  0.523
# Epoch:  850  | Train loss:  0.23650849  | Test acc:  0.5375
# Epoch:  860  | Train loss:  0.2218646  | Test acc:  0.525
# Epoch:  870  | Train loss:  0.21375367  | Test acc:  0.5325
# Epoch:  880  | Train loss:  0.20219925  | Test acc:  0.5295
# Epoch:  890  | Train loss:  0.19561744  | Test acc:  0.534
# Epoch:  900  | Train loss:  0.18458137  | Test acc:  0.5425
# Epoch:  910  | Train loss:  0.1759635  | Test acc:  0.537
# Epoch:  920  | Train loss:  0.16767277  | Test acc:  0.53
# Epoch:  930  | Train loss:  0.16115388  | Test acc:  0.53
# Epoch:  940  | Train loss:  0.15337735  | Test acc:  0.5385
# Epoch:  950  | Train loss:  0.14601341  | Test acc:  0.5295
# Epoch:  960  | Train loss:  0.14051187  | Test acc:  0.5325
# Epoch:  970  | Train loss:  0.13192861  | Test acc:  0.5385
# Epoch:  980  | Train loss:  0.12867877  | Test acc:  0.542
# Epoch:  990  | Train loss:  0.122123435  | Test acc:  0.5305
# Epoch:  999  | Train loss:  0.11813659  | Test acc:  0.5355

# %%
        # Plot train loss vs test acc
        plt.figure(figsize=(10, 8), dpi=100)
        plt.suptitle('Momentum term with momentum y=0.1')
        plt.plot(range(epochs), train_loss, label='Train Loss')
        plt.plot(range(epochs), test_acc, label='Test Accuracy')
        plt.xlabel('Epochs')
        plt.ylabel('Accuracy/loss')
        plt.legend()
        plt.savefig('./3a.Momentum_SGD_TrainLoss_TestAcc.png')
        plt.show()
